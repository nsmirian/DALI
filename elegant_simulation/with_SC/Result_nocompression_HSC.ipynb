# %% [markdown]
# ## Simulation of DALI MIR beam line
# ## cmpression , without SC

# %%
import sys, os
sys.path.append(os.path.abspath('/Users/mirian81/pyhton/Elegant_python_scripts'))
import twis_plot as TWPlot
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# initializing ocelot...

# %%
os.system('elegant dali.ele')
# Out:
# Running elegant at Wed Feb  5 15:31:57 2025
#
# This is elegant 2023.4, Dec 12 2023, by M. Borland, J. Calvey, M. Carla', N. Carmignani, AJ Dick, Z. Duan, M. Ehrlichman, L. Emery, W. Guo, N. Kuklev, R. Lindberg, V. Sajaev, R. Soliday, Y.-P. Sun, M. Wallbank, C.-X. Wang, Y. Wang, Y. Wu, and A. Xiao.
# ...
# Thanks for using elegant.  Please cite the following reference in your publications:
#   M. Borland, "elegant: A Flexible SDDS-Compliant Code for Accelerator Simulation,"
#   Advanced Photon Source LS-287, September 2000.
# If you use a modified version, please indicate this in all publications.
# ...
# Link date: Dec 12 2023 15:15:38, SVN revision: 30180M
# statistics:    ET:  00:00:0.000 CP:    0.00 BIO:0 DIO:0 PF:0 MEM:0
# &run_setup
#     lattice = DALI_lattice.lte,
#     use_beamline = Gun_to_MIR,
#     rootname = {NULL},
#     output = %s.out,
#     centroid = 1,
#     bpm_centroid = {NULL},
#     sigma = %s.sig,
#     final = %s.final,
#     acceptance = {NULL},
#     losses = {NULL},
# ...

# %%
#ls  % 90 sto phase_A no compression 
TWPlot.Twiss('dali.twi')
# Out:
# Data extracted from dali.twi to twi.data

# %%
TWPlot.threeDphase_space('dali.inj')
# Out:
# Data extracted from dali.inj to particle.out.data
# ParticleArray:
# Ref. energy : 0.0056 GeV
# Ave. energy : 0.0056 GeV
# std(x)      : 3.272 mm
# std(px)     : 1.296 mrad
# std(y)      : 3.27 mm
# std(py)     : 1.295 mrad
# std(p)      : 0.0096
# std(tau)    : 1.228 mm
# Charge      : 1.0 nC
# s pos       : 0 m
# n particles : 999999

# %%
TWPlot.threeDphase_space('dali.linac')
# Out:
# Data extracted from dali.linac to particle.out.data
# ParticleArray:
# Ref. energy : 0.0535 GeV
# Ave. energy : 0.0535 GeV
# std(x)      : 1.064 mm
# std(px)     : 0.104 mrad
# std(y)      : 0.5 mm
# std(py)     : 0.161 mrad
# std(p)      : 0.0012
# std(tau)    : 1.142 mm
# Charge      : 1.0 nC
# s pos       : 0 m
# n particles : 999999

# %%
TWPlot.threeDphase_space('dali.MIR')
# Out:
# Data extracted from dali.MIR to particle.out.data
# ParticleArray:
# Ref. energy : 0.0535 GeV
# Ave. energy : 0.0535 GeV
# std(x)      : 0.463 mm
# std(px)     : 1.227 mrad
# std(y)      : 0.395 mm
# std(py)     : 1.779 mrad
# std(p)      : 0.0015
# std(tau)    : 0.771 mm
# Charge      : 1.0 nC
# s pos       : 0 m
# n particles : 999999
