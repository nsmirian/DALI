# %% [markdown]
# # DALI tracking to Positron source
# # first order, no collective effect
#
# ## Najmeh Mirian
#
# 21 Jan 2025
#
# Here we have the lattices of Positron source and transfer line to FIR laser.

# %%
import IPython
import numpy
import time
import scipy
import matplotlib
import ocelot
print('ocelot:', ocelot.__version__)
from __future__ import print_function
# %matplotlib inline
from ocelot import *
#from Ocelot graphical modules
from ocelot.gui.accelerator import *
from copy import deepcopy
from DALI_lattice import *
# Out:
# initializing ocelot...
# ocelot: 24.03.0
# 0.7853981633974483 0.23561944901923448 0.19634954084936207
# 0.2617993877991494

# %%
lat_DALI_PS = MagneticLattice(Gun2PS)

# %%
p_array_init = load_particle_array("injection_gun_beamm.npz")

# %%
navi = Navigator(lat_DALI_PS)
p_array = deepcopy(p_array_init)
start = time.time()
tws_track, p_array = track(lat_DALI_PS, p_array, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 20.665238898038467 / 20.665238898038467. Applied:
#  time exec: 0.25939297676086426 sec

# %%
plot_opt_func(lat_DALI_PS, tws_track, top_plot=["Dx", "Dy"],fig_name=0, legend=False)
plt.show()

# %%
tws_Tranport_to_PS = twiss(lat_DALI_PS,tws_track[0] ,nPoints=1000)

# plot optical functions.
plot_opt_func(lat_DALI_PS, tws_Tranport_to_PS, top_plot = ["Dx", "Dy"], legend=False, font_size=10)
plt.show()

# %%
sigma_x = np.sqrt([tw.xx for tw in tws_track])
s = [tw.s for tw in tws_track]

plt.plot(s, sigma_x)
plt.xlabel("s [m]")
plt.ylabel(r"$\sigma_x$, [m]")
plt.show()

# %%
show_e_beam(p_array_init, figsize=(8,6))
plt.show()

# %%
show_e_beam(p_array, figsize=(8,6))
plt.show()

# %%
g=53/0.51
print(np.sqrt(10.665369301003443*7.68675711451365e-08*g))
print(7.68675711451365e-08*g)
# Out:
# 0.009230226855209746
# 7.988198569984774e-06

# %%
print(tws_track[-1])
# Out:
# emit_x  = 7.697079477853195e-08
# emit_y  = 7.874483262514538e-08
# beta_x  = 1.7078531219596196
# beta_y  = 1.0344620513716796
# alpha_x = -3.3147613059920342
# alpha_y = -1.6850533474284306
# gamma_x = 7.019129667279112
# gamma_y = 3.711498917324973
# Dx      = 0.0
# Dy      = 0.0
# Dxp     = 0.0
# Dyp     = 0.0
# mux     = 0.0
# muy     = 0.0
# nu_x    = 0.0
# nu_y    = 0.0
# E       = 0.05352127
# s        = 20.665238898038467

# %%
len(tws_track)
# Out:
# 66

# %%
print(tws_Tranport_to_PS[-1])
# Out:
# emit_x  = 7.365138174912308e-07
# emit_y  = 7.534879456221737e-07
# beta_x  = 1.7078617067450956
# beta_y  = 1.0344621584070381
# alpha_x = -3.314794914520597
# alpha_y = -1.6850705087944267
# gamma_x = 7.019224845891367
# gamma_y = 3.7115544424757623
# Dx      = 1.6928803810360884e-07
# Dy      = 0.0
# Dxp     = 1.1372745557435637e-07
# Dyp     = 0.0
# mux     = 9.548303336903974
# muy     = 9.3403315738429
# nu_x    = 1.5196596742091064
# nu_y    = 1.4865599400943998
# E       = 0.053521273881483936
# s        = 20.665238898038467
