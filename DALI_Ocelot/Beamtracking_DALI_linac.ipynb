# %% [markdown]
# DALI machine optics
#
# Najmeh Mirian
#
# 21 Jan 2025
#
# Here we have the lattices of Positron source and transfer line to FIR laser.

# %%
import IPython
import numpy
import time
import scipy
import matplotlib
import ocelot
print('ocelot:', ocelot.__version__)
from __future__ import print_function
# %matplotlib inline
from ocelot import *
#from Ocelot graphical modules
from ocelot.gui.accelerator import *
from copy import deepcopy
from DALI_lattice import *
# Out:
# initializing ocelot...
# ocelot: 24.03.0

# %%
lat_DALI_linac = MagneticLattice(T02T1)

# %%
p_array_init = load_particle_array("injection_gun_beamm.npz")

# %%
navi = Navigator(lat_DALI_linac)
p_array = deepcopy(p_array_init)
start = time.time()
tws_track, p_array = track(lat_DALI_linac, p_array, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 14.094 / 14.094000000000001. Applied: 1. Applied:
#  time exec: 0.18863987922668457 sec

# %%
plot_opt_func(lat_DALI_linac, tws_track, top_plot=["E"], fig_name=0, legend=False)
plt.show()

# %%
sigma_x = np.sqrt([tw.xx for tw in tws_track])
s = [tw.s for tw in tws_track]

plt.plot(s, sigma_x)
plt.xlabel("s [m]")
plt.ylabel(r"$\sigma_x$, [m]")
plt.show()

# %%
show_e_beam(p_array_init, figsize=(8,6))
plt.show()

# %%
show_e_beam(p_array, figsize=(8,6))
plt.show()

# %%
g=53/0.51
print(np.sqrt(10.665369301003443*7.68675711451365e-08*g))
print(7.68675711451365e-08*g)
# Out:
# 0.009230226855209746
# 7.988198569984774e-06

# %%
print(tws_track[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(tws_track[-1])
#
# NameError: name 'tws_track' is not defined

# %%
print(tws_track[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(tws_track[0])
#
# NameError: name 'tws_track' is not defined
